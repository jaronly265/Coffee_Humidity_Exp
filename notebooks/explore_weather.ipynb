# %% [markdown]
# # Explore Weather
#
# Create your own EDA below! Create as many code-blocks as you need.
#
# Once you've completed your EDA, complete the section titled **Reflections** where you will answer questions about your EDA.

# %%
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import data
weather1 = pd.read_csv("../data/weather/weather_data1.csv")
weather2 = pd.read_csv("../data/weather/weather_data2.csv")

# %%
# TODO: concatenate your data files together and save to a new csv file ("../data/weather/weather_data.csv")
weather_all = pd.concat([weather1, weather2])

weather_all.to_csv('../data/weather/weather_all.csv', index=False)

# %%
# TODO: view first 5 rows of your data
weather_all.head()
# Out:
#    year  rain_max   temp_avg   temp_max   temp_min    hum_max    hum_min  \
# 0  2006  6.670968  21.803087  27.190323  18.654839  97.129032  57.806452
# 1  2007  1.866250  23.040999  27.649375  18.753125  87.837500  48.493750
# 2  2008  3.777049  20.682400  27.000000  16.216393  96.136612  51.415301
# 3  2009  3.380220  21.023802  27.769231  16.410440  96.054945  49.329670
# 4  2010  2.183516  21.444293  28.580769  16.156044  95.247253  44.648352
#
#    wind_max  wind_avg   subdivision
# 0  9.706452  2.075207  Minas Gerais
# 1  8.749375  2.069605  Minas Gerais
# 2  8.865027  1.584408  Minas Gerais
# 3  9.114286  1.611746  Minas Gerais
# 4  9.109341  1.455907  Minas Gerais

# %%
# TODO: describe your numeric columns
weather_all.describe()
# Out:
#               year   rain_max   temp_avg   temp_max   temp_min    hum_max  \
# count    18.000000  18.000000  18.000000  18.000000  18.000000  18.000000
# mean   2014.500000   3.175087  21.285831  28.198312  16.458525  96.502990
# std       5.338539   1.190658   0.549483   0.564714   0.891070   2.345644
# min    2006.000000   1.617582  20.682400  27.000000  15.268681  87.837500
# 25%    2010.250000   2.342250  20.975602  27.811486  16.041470  96.079483
# 50%    2014.500000   2.978022  21.126061  28.406027  16.319722  97.089241
# 75%    2018.750000   3.718815  21.434377  28.614973  16.459066  97.553044
# max    2023.000000   6.670968  23.040999  29.010989  18.753125  98.500000
#
#          hum_min   wind_max   wind_avg
# count  18.000000  18.000000  18.000000
# mean   48.528039   8.469412   1.286295
# std     3.010135   0.611327   0.399773
# min    44.648352   7.484426   0.812202
# 25%    47.154325   7.906319   0.911424
# 50%    48.450172   8.489286   1.216155
# ...

# %%
# TODO: display the null values in your dataframe
weather_all.isna().sum()
# Out:
# year           0
# rain_max       0
# temp_avg       0
# temp_max       0
# temp_min       0
# hum_max        0
# hum_min        0
# wind_max       0
# wind_avg       0
# subdivision    0
# dtype: int64

# %%
weather_all.nunique()
# Out:
# year           18
# rain_max       18
# temp_avg       18
# temp_max       18
# temp_min       18
# hum_max        18
# hum_min        17
# wind_max       18
# wind_avg       18
# subdivision     1
# dtype: int64

# %%
weather_all.isnull()
# Out:
#     year  rain_max  temp_avg  temp_max  temp_min  hum_max  hum_min  wind_max  \
# 0  False     False     False     False     False    False    False     False
# 1  False     False     False     False     False    False    False     False
# 2  False     False     False     False     False    False    False     False
# 3  False     False     False     False     False    False    False     False
# 4  False     False     False     False     False    False    False     False
# 5  False     False     False     False     False    False    False     False
# 6  False     False     False     False     False    False    False     False
# 7  False     False     False     False     False    False    False     False
# 8  False     False     False     False     False    False    False     False
# 0  False     False     False     False     False    False    False     False
# 1  False     False     False     False     False    False    False     False
# ...

# %%
# TODO: BEGIN YOUR EDA!
#isolate data for Minas Gerais with pivot table of 
#weather_all.plot.line(y='temp_avg', x='year')

df = pd.pivot_table(weather_all, index =['year'], values =['temp_avg'] )
print(df)


df.plot(y='temp_avg', figsize=(20,12))
# Out:
#        temp_avg
# year
# 2006  21.803087
# 2007  23.040999
# 2008  20.682400
# 2009  21.023802
# 2010  21.444293
# 2011  20.959536
# 2012  21.030624
# 2013  21.088660
# 2014  21.163462
# 2015  21.346828
# 2016  21.630402
# 2017  21.404627
# 2018  21.325718
# 2019  21.733539
# 2020  20.884335
# 2021  20.831525
# 2022  20.704556
# 2023  21.046566
# <Axes: xlabel='year'>

# %% [markdown]
# ## Reflections
#
# Answer each question based on the visualizations that you've generated.
#
# Remember, you must justify your answers with proof! Look back to W6D3 for more context.

# %% [markdown]
# How is average temperature changing across the years for Minas Gerais? Is this increasing or decreasing?
# The average temperature is jumping up and down but is overall trending downwards so decreasing.

# %% [markdown]
# How is minimum humidity changing across the years for Minas Gerais? Is this increasing or decreasing?
#
# Other than an outlier in 2006, the minimum humidity is volatile. It spikes up and down but alwasy hovers at around 49. The calculated mean is actually 48.52.

# %%
Hum_pivot = pd.pivot_table(weather_all, index =['year'], values =['hum_min'] )
print(Hum_pivot)

print(weather_all['hum_min'].mean())

Hum_pivot.plot(figsize=(20,12))
# Out:
#         hum_min
# year
# 2006  57.806452
# 2007  48.493750
# 2008  51.415301
# 2009  49.329670
# 2010  44.648352
# 2011  49.252747
# 2012  46.366120
# 2013  49.390110
# 2014  44.824176
# 2015  48.406593
# 2016  47.587209
# 2017  47.475410
# 2018  47.047297
# 2019  48.230769
# 2020  51.005464
# 2021  44.824176
# 2022  48.543956
# 2023  48.857143
# 48.52803864471602
# <Axes: xlabel='year'>

# %% [markdown]
# How is average wind speed changing across the years for Minas Gerais? Is this increasing or decreasing?
#
# Average wind speed is decreasing. There's a 1.26 m/s drop in the avg from 2006 to 2023

# %%
Avg_wind = pd.pivot_table(weather_all, index= ['year'],values= ['wind_avg'])
print(Avg_wind)

Avg_wind.plot(figsize=(20,12))
# Out:
#       wind_avg
# year
# 2006  2.075207
# 2007  2.069605
# 2008  1.584408
# 2009  1.611746
# 2010  1.455907
# 2011  1.557709
# 2012  1.483515
# 2013  1.459356
# 2014  1.238874
# 2015  1.193435
# 2016  1.158309
# 2017  0.969464
# 2018  0.901090
# 2019  0.905517
# 2020  0.900751
# 2021  0.847070
# 2022  0.929144
# 2023  0.812202
# <Axes: xlabel='year'>

# %% [markdown]
# Which year had the highest maximum record rainfall?
# The highest maximum rainfall was in 2006 with 6.67 mm of rain.

# %%
max_rain = pd.pivot_table(weather_all, index= ['year'],values= ['rain_max'])
print(max_rain)

max_rain.max()

max_rain.plot(figsize=(20,12))
# Out:
#       rain_max
# year
# 2006  6.670968
# 2007  1.866250
# 2008  3.777049
# 2009  3.380220
# 2010  2.183516
# 2011  2.601786
# 2012  2.255738
# 2013  3.079121
# 2014  1.617582
# 2015  2.876923
# 2016  2.641860
# 2017  2.052459
# 2018  3.567568
# 2019  3.443956
# 2020  4.545355
# 2021  2.715385
# 2022  3.769231
# 2023  4.106593
# <Axes: xlabel='year'>

# %% [markdown]
# What is the relationship between max rain and max humidity? How *strong* is this relationship? Use pearson's correlation coefficient.
# There is a medium correlation between max rain and max humidity in a positive direction. Pearson's r is 1/.41

# %%
weather_all[["rain_max", "hum_max"]].corr()


sns.scatterplot(data=weather_all, x='rain_max', y='hum_max')
# Out:
# <Axes: xlabel='rain_max', ylabel='hum_max'>

# %% [markdown]
# What is the relationship between average wind speed and average temperature? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# There is medium correlation between average wind speed and average temp in a positive direction. The Pearson Correlation is 1/.48.

# %%
sns.scatterplot(data=weather_all, x='temp_avg', y='wind_avg')
weather_all[["temp_avg", "wind_avg"]].corr()
# Out:
#           temp_avg  wind_avg
# temp_avg  1.000000  0.476529
# wind_avg  0.476529  1.000000
